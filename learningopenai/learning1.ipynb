# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2'] = "true"

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model = "gpt-5.4-mini")

# %%
result = llm.invoke("what is generative ai?")
print(result)
# Out:
# content='Generative AI is a type of artificial intelligence that can **create new content** rather than only analyzing or classifying existing data.\n\n### Examples of what it can generate:\n- **Text** — articles, emails, stories, chat responses\n- **Images** — artwork, logos, photos\n- **Audio** — music, voice\n- **Video** — clips, animations\n- **Code** — software snippets and scripts\n\n### How it works, simply:\nGenerative AI learns patterns from large amounts of data, then uses those patterns to produce new outputs that look similar to the examples it was trained on.\n\n### Common tools:\n- ChatGPT for text\n- DALL·E, Midjourney, Stable Diffusion for images\n- GitHub Copilot for code\n\n### In short:\n**Traditional AI** often predicts or recognizes things.  \n**Generative AI** creates things.\n\nIf you want, I can also explain it in **very simple terms**, or give a **real-world example**.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 208, 'prompt_tokens': 12, 'total_tokens': 220, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EAqCCYBneckyAac8daN9WGbCBE3x2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--019fe4f4-10bc-76e3-be81-74d5637761ec-0' usage_metadata={'input_tokens': 12, 'output_tokens': 208, 'total_tokens': 220, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "you are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]
)

# %%
chain = prompt|llm

response = chain.invoke({"input":"can you tell me about langsmith?"})
print(response)
# Out:
# content='LangSmith is a **developer platform for building, debugging, testing, and monitoring LLM applications**. It’s especially useful if you’re working with **LangChain**, but it can also be used for other LLM workflows.\n\n### What it helps with\n- **Tracing**: See every step your LLM app takes, including prompts, tool calls, outputs, latency, and errors.\n- **Debugging**: Inspect chains, agents, retrieval flows, and model behavior to understand why something failed.\n- **Evaluation**: Run test datasets through your app and measure quality with automated or human feedback.\n- **Monitoring**: Track production usage, regressions, cost, latency, and reliability over time.\n\n### Core features\n- **Run traces**: Capture execution details of LLM calls and workflows.\n- **Datasets**: Store examples for testing and regression checks.\n- **Evaluations**: Compare outputs using metrics, LLM judges, or custom evaluators.\n- **Playground**: Test prompts and chains interactively.\n- **Feedback collection**: Add human review or scores to runs.\n\n### Why people use it\nWhen LLM apps fail, the issue is often not obvious:\n- prompt problems\n- bad retrieval results\n- tool-use failures\n- hallucinations\n- long latency or high cost\n\nLangSmith gives you visibility into all of that in one place.\n\n### Typical workflow\n1. Instrument your app with LangSmith tracing.\n2. Observe traces while developing.\n3. Create datasets from real examples.\n4. Run evaluations to compare prompt/model versions.\n5. Monitor production behavior and catch regressions.\n\n### Best for\n- LLM app developers\n- teams using LangChain/LangGraph\n- building RAG systems, agents, and multi-step workflows\n- anyone wanting stronger testing and observability for AI apps\n\nIf you want, I can also explain:\n- **how LangSmith compares to OpenTelemetry or MLflow**\n- **how to set it up in a Python app**\n- **how it works with LangChain/LangGraph**' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 423, 'prompt_tokens': 32, 'total_tokens': 455, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EAqcqgNDRsWVNCC3cmcG2uo9Uwb8B', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--019fe50d-460c-7e43-819c-b69a41b2c22b-0' usage_metadata={'input_tokens': 32, 'output_tokens': 423, 'total_tokens': 455, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":"can you tell me about langsmith?"})
print(response)
# Out:
# LangSmith is a platform from LangChain that helps you **build, debug, test, and monitor LLM applications**.
#
# ### In simple terms
# If you're working with:
# - chatbots
# - RAG systems
# - agents
# - LLM workflows
#
# LangSmith helps you understand:
# - **what prompts were sent**
# - **what the model responded**
# - **where failures happened**
# - **how to improve quality over time**
#
# ### Main things LangSmith is used for
# 1. **Tracing**
#    - See every step of an LLM app execution
#    - Useful for debugging chains, agents, tool calls, and retrievers
#
# 2. **Debugging**
#    - Inspect prompts, inputs, outputs, and intermediate steps
#    - Find where hallucinations or bad outputs come from
#
# 3. **Evaluation**
#    - Run test datasets against your app
#    - Compare prompt versions, models, or retrieval strategies
#    - Measure quality with automated or human review
#
# 4. **Monitoring**
#    - Track production runs
#    - Observe latency, errors, cost, and output quality
#    - Detect regressions after deployments
#
# ### Why people use it
# LLM apps can be hard to debug because behavior is non-deterministic. LangSmith gives you visibility into:
# - prompt changes
# - model behavior
# - agent decisions
# - retrieval quality
# - tool usage
#
# ### Example use case
# If your RAG app gives a wrong answer, LangSmith can help you see:
# - whether the retriever found bad documents
# - whether the prompt was unclear
# - whether the model ignored context
# - which step caused the issue
#
# ### Related ecosystem
# LangSmith works well with:
# - **LangChain**
# - **LangGraph**
# - custom Python/JS LLM apps
#
# If you want, I can also explain:
# 1. **how LangSmith works under the hood**
# 2. **how to integrate it in Python**
# 3. **how it compares with OpenAI tracing / Langfuse / Arize**
