# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model='openai/gpt-oss-120b',groq_api_key = groq_api_key)

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages = [
    SystemMessage(content="Translate the following from English to hindi"),
    HumanMessage(content="a beautifulday whit a beautiful sunshine ")

]

result = model.invoke(messages)

# %%
 from langchain_core.output_parsers import StrOutputParser
 parser = StrOutputParser()
 parser.invoke(result)
# Out:
# 'आप कैसे हैं?'

# %%
chain = model|parser
chain.invoke(messages)
# Out:
# 'एक सुंदर दिन, सुंदर धूप के साथ।'

# %%
from langchain_core.prompts import ChatPromptTemplate

generic_template = "translate the following into {language}"

prompt = ChatPromptTemplate.from_messages(
    [
        ('system',generic_template),
        ('user','{text}')
    ]
)

# %%
result = prompt.invoke({"language":"hindi","text":"you dumbass"})
result.to_messages()
# Out:
# [SystemMessage(content='translate the following into hindi', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='you dumbass', additional_kwargs={}, response_metadata={})]

# %%
chain = prompt|model|parser
chain.invoke({"language":"hindi","text":"what the fuck"})
# Out:
# '**Hindi translation:**  \n“क्या बकवास है?”\u202f(यह वाक्यांश बहुत ही अश्लील/अशिष्ट है, इसलिए इसका उपयोग सावधानी से करें।)'
